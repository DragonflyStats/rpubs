# %% [markdown]
# Mahalanobis Distances uses estimates of the location and scatter to
# identify values that are far away from the main distribution of data

# %%
library(ggplot2)
library(dplyr)

# %%
data(diamonds)
df <- sample_frac(diamonds,0.3)
head(df)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.42  Premium   F     VVS2    61.7  59     1142 4.78 4.82 2.96
# 2 2.00  Very Good G     SI1     62.5  58    18186 7.98 8.04 5.01
# 3 0.71  Premium   E     SI2     62.7  59     2322 5.66 5.70 3.56
# 4 0.44  Ideal     E     VS2     61.6  54      936 4.90 4.97 3.04
# 5 0.54  Ideal     D     VVS2    61.2  55     2323 5.31 5.25 3.23
# 6 0.42  Ideal     G     VS1     61.2  54      984 4.86 4.82 2.96

# %%
# Calculate Mahalanobis Distance with height and weight distributions
MD <- mahalanobis(df[, c(1,5,7)], colMeans(df[,c(1,5,7)]), cov(df[, c(1,5,7)]))

# %%
cov(df[,c(1,5,7)])
# Out:
#       carat        depth        price
# carat 2.209971e-01   0.01831018  1.715026e+03
# depth 1.831018e-02   2.02454766 -8.536086e+01
# price 1.715026e+03 -85.36086016  1.571874e+07

# %%
df$MD <- round(MD, 3)

# %%
MD[1:300] %>% round(2)
# Out:
#   [1]  0.64 17.26  0.76  0.60  0.48  0.78  0.56  0.82  1.86 26.17  1.27  0.41
#  [13]  1.51  0.72  2.43  7.06  2.74  3.02  2.88  3.02  0.81  0.39  0.54  0.23
#  [25]  1.42 16.23  8.33  1.11  5.56  0.19  0.94  2.91  5.70  3.02  0.21  1.76
#  [37]  1.11  1.47  0.83  0.69  3.87  0.46 14.10  1.48  1.25  2.26  1.71 30.21
#  [49]  0.75  3.02 33.46  2.78  2.62  8.68  0.40  3.33  1.07  0.67  0.76  0.66
#  [61]  2.77  5.79  1.18  1.13  4.40  0.31  3.86  1.40  0.82  3.96  3.05  0.21
#  [73]  1.80  1.61  0.67  8.12  0.31  0.65  1.06 15.93  7.27  2.78  1.32  1.29
#  [85]  1.29  8.57  5.75  0.79  2.21  0.50  7.69  8.95  1.17  0.43  1.15  0.90
#  [97] 10.65  0.48  2.35  4.94  0.99  3.68  3.76  0.56  1.53  0.73  0.58  0.26
# [109]  1.01  0.46  6.75  1.09 16.14  0.11  1.46  2.00  3.39  1.05  0.60  9.49
# [121]  0.76  1.55  3.19  0.74  2.57  0.46  0.87  1.06  5.35  0.92  5.26  3.59
# [133]  0.75  0.87  0.44  0.37  1.47  1.24  0.42  0.79  9.58  2.42  0.91  0.99
# [145]  2.06  2.77  2.20  2.88  2.22  1.07  3.18  1.23  0.93  5.01  1.29  5.70
# [157] 15.16  0.88  1.09  0.16  1.69  2.32  1.19  0.91  2.26  1.16 17.22  0.92
# [169]  1.19  1.59  0.13  1.39  1.33  0.11  3.55  1.48  1.04  0.45  1.11  1.02
# [181]  1.53  1.96  1.05  1.48  1.98  3.04  1.90  1.99  0.44  1.29  3.35 10.35
# [193]  4.73  5.58  0.40  2.37  0.86  0.37  0.96  1.62  1.15  1.06  1.06  1.20
# [205] 10.80  1.70  0.10  0.63  6.17  1.10  0.65  2.81  1.44  7.90 18.42  0.41
# [217]  5.49  1.38  0.98  1.14  0.11  0.86  6.32  1.07  0.91  1.03  3.75  2.57
# [229]  0.40  0.90  1.79  0.30  0.65  0.91 11.65  0.40  5.43  2.46  2.00  2.51
# [241]  9.22  0.48  1.05  0.99  6.46  0.56  0.65  5.15  2.31  1.03  1.19  0.97
# [253]  0.56  0.83  1.12  1.18  0.72 13.21  3.94  0.14  5.71  4.60  0.59 12.07
# [265]  1.46  1.88  4.60  1.20  1.18  4.35  0.50  0.62  3.06  1.27  0.82  0.68
# [277]  3.05  1.18  3.04 15.49  7.38  0.60 13.51 28.38  1.99  1.11  2.26  3.50
# [289]  1.77  3.30  3.72  1.03  1.21  0.43  1.24  2.21  0.34  1.35  7.97  0.34

# %%
head(df)
# Out:
#   carat cut       color clarity depth table price x    y    z    outlier_maha
# 1 0.42  Premium   F     VVS2    61.7  59     1142 4.78 4.82 2.96 FALSE
# 2 2.00  Very Good G     SI1     62.5  58    18186 7.98 8.04 5.01  TRUE
# 3 0.71  Premium   E     SI2     62.7  59     2322 5.66 5.70 3.56 FALSE
# 4 0.44  Ideal     E     VS2     61.6  54      936 4.90 4.97 3.04 FALSE
# 5 0.54  Ideal     D     VVS2    61.2  55     2323 5.31 5.25 3.23 FALSE
# 6 0.42  Ideal     G     VS1     61.2  54      984 4.86 4.82 2.96 FALSE
#   m_dist MD
# 1  0.49   0.645
# 2 13.30  17.260
# 3  0.59   0.759
# 4  0.58   0.600
# 5  0.32   0.483
# 6  0.71   0.775

# %%
# Mahalanobis Outliers - Threshold set to 12
df$outlier_maha <- FALSE
df$outlier_maha[df$MD > 10] <- TRUE

# %%
head(df)
# Out:
#   carat cut       color clarity depth table price x    y    z    outlier_maha
# 1 0.42  Premium   F     VVS2    61.7  59     1142 4.78 4.82 2.96 FALSE
# 2 2.00  Very Good G     SI1     62.5  58    18186 7.98 8.04 5.01  TRUE
# 3 0.71  Premium   E     SI2     62.7  59     2322 5.66 5.70 3.56 FALSE
# 4 0.44  Ideal     E     VS2     61.6  54      936 4.90 4.97 3.04 FALSE
# 5 0.54  Ideal     D     VVS2    61.2  55     2323 5.31 5.25 3.23 FALSE
# 6 0.42  Ideal     G     VS1     61.2  54      984 4.86 4.82 2.96 FALSE
#   m_dist MD
# 1  0.49   0.645
# 2 13.30  17.260
# 3  0.59   0.759
# 4  0.58   0.600
# 5  0.32   0.483
# 6  0.71   0.775
